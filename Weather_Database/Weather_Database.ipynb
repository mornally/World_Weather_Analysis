# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import requests

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]

        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]     
        city_weather_description = city_weather["weather"][0]["description"]   
      
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | voyvozh
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | manado
# Processing Record 4 of Set 1 | goure
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | carbonia
# Processing Record 7 of Set 1 | karasjok
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | ust-tsilma
# Processing Record 10 of Set 1 | pevek
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 1 | kaitangata
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | ndende
# Processing Record 17 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | yar-sale
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | lata
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | umm lajj
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | poum
# Processing Record 34 of Set 1 | avera
# Processing Record 35 of Set 1 | hamilton
# Processing Record 36 of Set 1 | lakes entrance
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | mudbidri
# Processing Record 40 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 1 | mayo
# Processing Record 42 of Set 1 | hasaki
# Processing Record 43 of Set 1 | cockburn town
# Processing Record 44 of Set 1 | porto novo
# Processing Record 45 of Set 1 | kot putli
# City not found. Skipping...
# Processing Record 46 of Set 1 | deputatskiy
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | antigonish
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | balatonszabadi
# Processing Record 2 of Set 2 | mehamn
# Processing Record 3 of Set 2 | ust-maya
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | leningradskiy
# Processing Record 6 of Set 2 | port blair
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | wonosobo
# Processing Record 9 of Set 2 | iskateley
# Processing Record 10 of Set 2 | nola
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | bonavista
# Processing Record 14 of Set 2 | ruidoso
# Processing Record 15 of Set 2 | nhulunbuy
# Processing Record 16 of Set 2 | bac lieu
# Processing Record 17 of Set 2 | samarai
# Processing Record 18 of Set 2 | kysyl-syr
# Processing Record 19 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 2 | tuatapere
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | port keats
# Processing Record 23 of Set 2 | thohoyandou
# Processing Record 24 of Set 2 | severo-kurilsk
# Processing Record 25 of Set 2 | hameenlinna
# Processing Record 26 of Set 2 | port macquarie
# Processing Record 27 of Set 2 | goalpara
# Processing Record 28 of Set 2 | banda aceh
# Processing Record 29 of Set 2 | cusuna
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | valparaiso
# Processing Record 32 of Set 2 | jiaonan
# Processing Record 33 of Set 2 | rosarito
# Processing Record 34 of Set 2 | dwarka
# Processing Record 35 of Set 2 | ascension
# Processing Record 36 of Set 2 | lakhnadon
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | pochutla
# Processing Record 41 of Set 2 | kavieng
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | victoria
# Processing Record 44 of Set 2 | pisco
# Processing Record 45 of Set 2 | flin flon
# Processing Record 46 of Set 2 | olden
# Processing Record 47 of Set 2 | semey
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | faanui
# Processing Record 50 of Set 2 | beloha
# Processing Record 1 of Set 3 | riyadh
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | mount barker
# Processing Record 5 of Set 3 | oropoli
# Processing Record 6 of Set 3 | teknaf
# Processing Record 7 of Set 3 | bakchar
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | mizan teferi
# Processing Record 10 of Set 3 | carhuamayo
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | ponta do sol
# Processing Record 13 of Set 3 | longyearbyen
# Processing Record 14 of Set 3 | ginda
# Processing Record 15 of Set 3 | dali
# Processing Record 16 of Set 3 | zvishavane
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | saurimo
# Processing Record 19 of Set 3 | dingle
# Processing Record 20 of Set 3 | meulaboh
# Processing Record 21 of Set 3 | ayan
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | erzin
# Processing Record 26 of Set 3 | hirara
# Processing Record 27 of Set 3 | iqaluit
# Processing Record 28 of Set 3 | morgan hill
# Processing Record 29 of Set 3 | san jose
# Processing Record 30 of Set 3 | conceicao do almeida
# Processing Record 31 of Set 3 | manokwari
# Processing Record 32 of Set 3 | kuala krai
# City not found. Skipping...
# Processing Record 33 of Set 3 | banjar
# Processing Record 34 of Set 3 | constitucion
# Processing Record 35 of Set 3 | bambanglipuro
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | nome
# Processing Record 38 of Set 3 | tazmalt
# Processing Record 39 of Set 3 | tiksi
# Processing Record 40 of Set 3 | liverpool
# Processing Record 41 of Set 3 | qaqortoq
# Processing Record 42 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 3 | touros
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | vao
# Processing Record 46 of Set 3 | sao filipe
# Processing Record 47 of Set 3 | georgetown
# Processing Record 48 of Set 3 | norman wells
# Processing Record 49 of Set 3 | bluff
# Processing Record 50 of Set 3 | barrow
# Processing Record 1 of Set 4 | maniitsoq
# Processing Record 2 of Set 4 | trincomalee
# Processing Record 3 of Set 4 | caravelas
# Processing Record 4 of Set 4 | salalah
# Processing Record 5 of Set 4 | puerto ayora
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | chunskiy
# Processing Record 8 of Set 4 | new norfolk
# Processing Record 9 of Set 4 | padang
# Processing Record 10 of Set 4 | chilca
# Processing Record 11 of Set 4 | kattivakkam
# Processing Record 12 of Set 4 | onoda
# Processing Record 13 of Set 4 | dakar
# Processing Record 14 of Set 4 | port-gentil
# Processing Record 15 of Set 4 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 16 of Set 4 | kasongo-lunda
# Processing Record 17 of Set 4 | shimoda
# Processing Record 18 of Set 4 | matara
# Processing Record 19 of Set 4 | hobart
# Processing Record 20 of Set 4 | wanning
# Processing Record 21 of Set 4 | bad wurzach
# Processing Record 22 of Set 4 | porto santo
# Processing Record 23 of Set 4 | bengkulu
# Processing Record 24 of Set 4 | prince rupert
# Processing Record 25 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 4 | batticaloa
# Processing Record 27 of Set 4 | kisangani
# Processing Record 28 of Set 4 | krasnoyarskiy
# Processing Record 29 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 30 of Set 4 | chowchilla
# Processing Record 31 of Set 4 | klaksvik
# Processing Record 32 of Set 4 | kaliganj
# Processing Record 33 of Set 4 | portland
# Processing Record 34 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 4 | svetlogorsk
# Processing Record 36 of Set 4 | araouane
# Processing Record 37 of Set 4 | marystown
# Processing Record 38 of Set 4 | namibe
# Processing Record 39 of Set 4 | santa isabel do rio negro
# Processing Record 40 of Set 4 | morant bay
# Processing Record 41 of Set 4 | agirish
# Processing Record 42 of Set 4 | cayenne
# Processing Record 43 of Set 4 | marawi
# Processing Record 44 of Set 4 | mitsamiouli
# Processing Record 45 of Set 4 | bani walid
# Processing Record 46 of Set 4 | cherskiy
# Processing Record 47 of Set 4 | san vicente
# Processing Record 48 of Set 4 | sofiysk
# City not found. Skipping...
# Processing Record 49 of Set 4 | ancud
# Processing Record 50 of Set 4 | nikolskoye
# Processing Record 1 of Set 5 | komatipoort
# Processing Record 2 of Set 5 | paka
# Processing Record 3 of Set 5 | jumla
# Processing Record 4 of Set 5 | savannah bight
# Processing Record 5 of Set 5 | cairns
# Processing Record 6 of Set 5 | evensk
# Processing Record 7 of Set 5 | nemuro
# Processing Record 8 of Set 5 | san patricio
# Processing Record 9 of Set 5 | novikovo
# Processing Record 10 of Set 5 | esperance
# Processing Record 11 of Set 5 | sao gabriel da cachoeira
# Processing Record 12 of Set 5 | lompoc
# Processing Record 13 of Set 5 | roald
# Processing Record 14 of Set 5 | prestea
# Processing Record 15 of Set 5 | gostilitsy
# Processing Record 16 of Set 5 | saint george
# Processing Record 17 of Set 5 | novoagansk
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | anadyr
# Processing Record 20 of Set 5 | vigia del fuerte
# Processing Record 21 of Set 5 | te anau
# Processing Record 22 of Set 5 | chiredzi
# Processing Record 23 of Set 5 | avarua
# Processing Record 24 of Set 5 | ambon
# Processing Record 25 of Set 5 | san cristobal
# Processing Record 26 of Set 5 | yeniseysk
# Processing Record 27 of Set 5 | quang ngai
# Processing Record 28 of Set 5 | ostrovnoy
# Processing Record 29 of Set 5 | sorland
# Processing Record 30 of Set 5 | lithakia
# Processing Record 31 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 5 | kasongo
# Processing Record 33 of Set 5 | taywarah
# Processing Record 34 of Set 5 | souillac
# Processing Record 35 of Set 5 | sayaxche
# Processing Record 36 of Set 5 | xuanwu
# Processing Record 37 of Set 5 | aragarcas
# Processing Record 38 of Set 5 | pangnirtung
# Processing Record 39 of Set 5 | ahipara
# Processing Record 40 of Set 5 | coquimbo
# Processing Record 41 of Set 5 | hit
# Processing Record 42 of Set 5 | englehart
# Processing Record 43 of Set 5 | berdigestyakh
# Processing Record 44 of Set 5 | itanhem
# Processing Record 45 of Set 5 | hambantota
# Processing Record 46 of Set 5 | krasnoselkup
# Processing Record 47 of Set 5 | clarence town
# Processing Record 48 of Set 5 | san rafael
# Processing Record 49 of Set 5 | palasa
# Processing Record 50 of Set 5 | kopyevo
# City not found. Skipping...
# Processing Record 1 of Set 6 | vardo
# Processing Record 2 of Set 6 | porto walter
# Processing Record 3 of Set 6 | luderitz
# Processing Record 4 of Set 6 | tugalan
# City not found. Skipping...
# Processing Record 5 of Set 6 | saint-pierre
# Processing Record 6 of Set 6 | kismayo
# Processing Record 7 of Set 6 | narsaq
# Processing Record 8 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 6 | saint-francois
# Processing Record 10 of Set 6 | luganville
# Processing Record 11 of Set 6 | mayumba
# Processing Record 12 of Set 6 | mkushi
# Processing Record 13 of Set 6 | dhidhdhoo
# Processing Record 14 of Set 6 | liepaja
# Processing Record 15 of Set 6 | moerai
# Processing Record 16 of Set 6 | monrovia
# Processing Record 17 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 6 | ponta delgada
# Processing Record 19 of Set 6 | ormara
# Processing Record 20 of Set 6 | tabou
# Processing Record 21 of Set 6 | emerald
# Processing Record 22 of Set 6 | saskylakh
# Processing Record 23 of Set 6 | mizdah
# Processing Record 24 of Set 6 | changde
# Processing Record 25 of Set 6 | springbok
# Processing Record 26 of Set 6 | port lincoln
# Processing Record 27 of Set 6 | sao joao da barra
# Processing Record 28 of Set 6 | rayong
# Processing Record 29 of Set 6 | mount gambier
# Processing Record 30 of Set 6 | zhigansk
# Processing Record 31 of Set 6 | egvekinot
# Processing Record 32 of Set 6 | carnduff
# Processing Record 33 of Set 6 | ilulissat
# Processing Record 34 of Set 6 | broome
# Processing Record 35 of Set 6 | yulara
# Processing Record 36 of Set 6 | port hardy
# Processing Record 37 of Set 6 | east london
# Processing Record 38 of Set 6 | mindelo
# Processing Record 39 of Set 6 | atlantic city
# Processing Record 40 of Set 6 | sinnamary
# Processing Record 41 of Set 6 | nisia floresta
# Processing Record 42 of Set 6 | at-bashi
# Processing Record 43 of Set 6 | comodoro rivadavia
# Processing Record 44 of Set 6 | berlevag
# Processing Record 45 of Set 6 | igarka
# Processing Record 46 of Set 6 | ryazanskaya
# Processing Record 47 of Set 6 | oia
# Processing Record 48 of Set 6 | bocicoiu mare
# Processing Record 49 of Set 6 | walvis bay
# Processing Record 50 of Set 6 | broken hill
# Processing Record 1 of Set 7 | blagoyevo
# Processing Record 2 of Set 7 | lemesos
# City not found. Skipping...
# Processing Record 3 of Set 7 | gigmoto
# Processing Record 4 of Set 7 | boende
# Processing Record 5 of Set 7 | igrim
# Processing Record 6 of Set 7 | khatanga
# Processing Record 7 of Set 7 | gizo
# Processing Record 8 of Set 7 | ambanja
# Processing Record 9 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 10 of Set 7 | zhigalovo
# Processing Record 11 of Set 7 | bubaque
# Processing Record 12 of Set 7 | rocha
# Processing Record 13 of Set 7 | dolores
# Processing Record 14 of Set 7 | xinqing
# Processing Record 15 of Set 7 | travesia
# Processing Record 16 of Set 7 | wageningen
# Processing Record 17 of Set 7 | cochrane
# Processing Record 18 of Set 7 | lagoa
# Processing Record 19 of Set 7 | lazaro cardenas
# Processing Record 20 of Set 7 | makokou
# Processing Record 21 of Set 7 | komsomolskiy
# Processing Record 22 of Set 7 | francisco beltrao
# Processing Record 23 of Set 7 | lufilufi
# Processing Record 24 of Set 7 | cervo
# Processing Record 25 of Set 7 | nchelenge
# Processing Record 26 of Set 7 | nyuksenitsa
# Processing Record 27 of Set 7 | castro
# Processing Record 28 of Set 7 | pachino
# Processing Record 29 of Set 7 | torres
# Processing Record 30 of Set 7 | shirgaon
# Processing Record 31 of Set 7 | grindavik
# Processing Record 32 of Set 7 | mareeba
# Processing Record 33 of Set 7 | kasempa
# Processing Record 34 of Set 7 | sur
# Processing Record 35 of Set 7 | bang saphan
# Processing Record 36 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 7 | enid
# Processing Record 38 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 7 | laguna
# Processing Record 40 of Set 7 | zhangye
# Processing Record 41 of Set 7 | vila velha
# Processing Record 42 of Set 7 | blind river
# Processing Record 43 of Set 7 | kalemie
# Processing Record 44 of Set 7 | tiznit
# Processing Record 45 of Set 7 | hollister
# Processing Record 46 of Set 7 | inyonga
# Processing Record 47 of Set 7 | changli
# Processing Record 48 of Set 7 | alofi
# Processing Record 49 of Set 7 | mutoko
# Processing Record 50 of Set 7 | antsohihy
# Processing Record 1 of Set 8 | lingao
# Processing Record 2 of Set 8 | bichura
# Processing Record 3 of Set 8 | ginir
# Processing Record 4 of Set 8 | kamakwie
# Processing Record 5 of Set 8 | mocuba
# Processing Record 6 of Set 8 | zhanaozen
# Processing Record 7 of Set 8 | sakakah
# Processing Record 8 of Set 8 | provideniya
# Processing Record 9 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 8 | novyy oskol
# Processing Record 12 of Set 8 | nuevo progreso
# Processing Record 13 of Set 8 | oistins
# Processing Record 14 of Set 8 | altay
# Processing Record 15 of Set 8 | tateyama
# Processing Record 16 of Set 8 | ambilobe
# Processing Record 17 of Set 8 | codrington
# Processing Record 18 of Set 8 | weligama
# Processing Record 19 of Set 8 | haapiti
# Processing Record 20 of Set 8 | dostpur
# Processing Record 21 of Set 8 | sitka
# Processing Record 22 of Set 8 | chibuto
# Processing Record 23 of Set 8 | mananjary
# Processing Record 24 of Set 8 | alta floresta
# Processing Record 25 of Set 8 | ulety
# Processing Record 26 of Set 8 | talnakh
# Processing Record 27 of Set 8 | tura
# Processing Record 28 of Set 8 | ixtapa
# Processing Record 29 of Set 8 | jacareacanga
# Processing Record 30 of Set 8 | yumen
# Processing Record 31 of Set 8 | takoradi
# Processing Record 32 of Set 8 | kyra
# Processing Record 33 of Set 8 | nanortalik
# Processing Record 34 of Set 8 | chuy
# Processing Record 35 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 8 | ankang
# Processing Record 37 of Set 8 | linjiang
# Processing Record 38 of Set 8 | kargil
# Processing Record 39 of Set 8 | the pas
# Processing Record 40 of Set 8 | belmonte
# Processing Record 41 of Set 8 | grand-santi
# Processing Record 42 of Set 8 | taoudenni
# Processing Record 43 of Set 8 | kavaratti
# Processing Record 44 of Set 8 | olafsvik
# Processing Record 45 of Set 8 | camflora
# City not found. Skipping...
# Processing Record 46 of Set 8 | pirai do sul
# Processing Record 47 of Set 8 | potsdam
# Processing Record 48 of Set 8 | nelson
# Processing Record 49 of Set 8 | biak
# Processing Record 50 of Set 8 | kostomuksha
# Processing Record 1 of Set 9 | hermosillo
# Processing Record 2 of Set 9 | airai
# Processing Record 3 of Set 9 | waddan
# Processing Record 4 of Set 9 | mykolayiv
# Processing Record 5 of Set 9 | alamosa
# Processing Record 6 of Set 9 | kushmurun
# Processing Record 7 of Set 9 | ayia varvara
# Processing Record 8 of Set 9 | kivsharivka
# Processing Record 9 of Set 9 | ures
# Processing Record 10 of Set 9 | hualmay
# Processing Record 11 of Set 9 | kahului
# Processing Record 12 of Set 9 | surovatikha
# Processing Record 13 of Set 9 | wawa
# Processing Record 14 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 9 | duz
# City not found. Skipping...
# Processing Record 16 of Set 9 | vestmannaeyjar
# Processing Record 17 of Set 9 | yashkul
# Processing Record 18 of Set 9 | sorong
# Processing Record 19 of Set 9 | college
# Processing Record 20 of Set 9 | atar
# Processing Record 21 of Set 9 | balikpapan
# Processing Record 22 of Set 9 | algiers
# Processing Record 23 of Set 9 | havre-saint-pierre
# Processing Record 24 of Set 9 | gatton
# Processing Record 25 of Set 9 | acapulco
# Processing Record 26 of Set 9 | ocos
# Processing Record 27 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 9 | kurtalan
# Processing Record 30 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 32 of Set 9 | hami
# Processing Record 33 of Set 9 | coahuayana
# Processing Record 34 of Set 9 | svetlaya
# Processing Record 35 of Set 9 | salinopolis
# Processing Record 36 of Set 9 | korla
# Processing Record 37 of Set 9 | otukpo
# Processing Record 38 of Set 9 | kirkwall
# Processing Record 39 of Set 9 | kapuskasing
# Processing Record 40 of Set 9 | ketchikan
# Processing Record 41 of Set 9 | myanaung
# Processing Record 42 of Set 9 | bandarbeyla
# Processing Record 43 of Set 9 | jalingo
# Processing Record 44 of Set 9 | najran
# Processing Record 45 of Set 9 | mandera
# Processing Record 46 of Set 9 | along
# Processing Record 47 of Set 9 | moussoro
# Processing Record 48 of Set 9 | fairbanks
# Processing Record 49 of Set 9 | chicama
# Processing Record 50 of Set 9 | dikson
# Processing Record 1 of Set 10 | whitehorse
# Processing Record 2 of Set 10 | richards bay
# Processing Record 3 of Set 10 | laela
# Processing Record 4 of Set 10 | geraldton
# Processing Record 5 of Set 10 | muscat
# Processing Record 6 of Set 10 | bobrov
# Processing Record 7 of Set 10 | saraza
# Processing Record 8 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 10 | batagay
# Processing Record 10 of Set 10 | mudgee
# Processing Record 11 of Set 10 | havoysund
# Processing Record 12 of Set 10 | muzhi
# Processing Record 13 of Set 10 | thano bula khan
# City not found. Skipping...
# Processing Record 14 of Set 10 | manga
# Processing Record 15 of Set 10 | dajal
# Processing Record 16 of Set 10 | kambove
# Processing Record 17 of Set 10 | general roca
# Processing Record 18 of Set 10 | isangel
# Processing Record 19 of Set 10 | bahia blanca
# Processing Record 20 of Set 10 | papayal
# Processing Record 21 of Set 10 | sisimiut
# Processing Record 22 of Set 10 | mwene-ditu
# Processing Record 23 of Set 10 | iguape
# Processing Record 24 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 10 | polonne
# Processing Record 26 of Set 10 | beringovskiy
# Processing Record 27 of Set 10 | chateaubelair
# Processing Record 28 of Set 10 | iisalmi
# Processing Record 29 of Set 10 | rawson
# Processing Record 30 of Set 10 | oranjemund
# Processing Record 31 of Set 10 | bell ville
# Processing Record 32 of Set 10 | minatitlan
# Processing Record 33 of Set 10 | frontera
# Processing Record 34 of Set 10 | hobyo
# Processing Record 35 of Set 10 | grenada
# Processing Record 36 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 37 of Set 10 | ashland
# Processing Record 38 of Set 10 | hwange
# Processing Record 39 of Set 10 | lorengau
# Processing Record 40 of Set 10 | brasilia de minas
# Processing Record 41 of Set 10 | lebedinyy
# Processing Record 42 of Set 10 | alice springs
# Processing Record 43 of Set 10 | tabuk
# Processing Record 44 of Set 10 | senanga
# Processing Record 45 of Set 10 | eskil
# Processing Record 46 of Set 10 | port said
# Processing Record 47 of Set 10 | gazanjyk
# Processing Record 48 of Set 10 | mae sai
# Processing Record 49 of Set 10 | port hedland
# Processing Record 50 of Set 10 | yerbogachen
# Processing Record 1 of Set 11 | bonthe
# Processing Record 2 of Set 11 | asau
# Processing Record 3 of Set 11 | mlonggo
# Processing Record 4 of Set 11 | colonia
# Processing Record 5 of Set 11 | natal
# Processing Record 6 of Set 11 | taunton
# Processing Record 7 of Set 11 | kinloss
# Processing Record 8 of Set 11 | doha
# Processing Record 9 of Set 11 | thanh hoa
# Processing Record 10 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 11 of Set 11 | barkhera
# Processing Record 12 of Set 11 | ibia
# Processing Record 13 of Set 11 | lokosovo
# Processing Record 14 of Set 11 | kununurra
# Processing Record 15 of Set 11 | pak phanang
# Processing Record 16 of Set 11 | angoram
# Processing Record 17 of Set 11 | cap malheureux
# Processing Record 18 of Set 11 | nelson bay
# Processing Record 19 of Set 11 | sola
# Processing Record 20 of Set 11 | enshi
# Processing Record 21 of Set 11 | eureka
# Processing Record 22 of Set 11 | gornopravdinsk
# Processing Record 23 of Set 11 | leshukonskoye
# Processing Record 24 of Set 11 | luau
# Processing Record 25 of Set 11 | aksarka
# Processing Record 26 of Set 11 | bilma
# Processing Record 27 of Set 11 | derzhavinsk
# Processing Record 28 of Set 11 | santa fe
# Processing Record 29 of Set 11 | savonlinna
# Processing Record 30 of Set 11 | dryden
# Processing Record 31 of Set 11 | fortuna
# Processing Record 32 of Set 11 | eden
# Processing Record 33 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 11 | praia da vitoria
# Processing Record 35 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 11 | barranca
# Processing Record 37 of Set 11 | yongan
# Processing Record 38 of Set 11 | gushikawa
# Processing Record 39 of Set 11 | pazardzik
# City not found. Skipping...
# Processing Record 40 of Set 11 | moron
# Processing Record 41 of Set 11 | itaueira
# Processing Record 42 of Set 11 | shache
# Processing Record 43 of Set 11 | haines junction
# Processing Record 44 of Set 11 | beyneu
# Processing Record 45 of Set 11 | humberto de campos
# Processing Record 46 of Set 11 | awjilah
# Processing Record 47 of Set 11 | puerto escondido
# Processing Record 48 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 11 | kaseda
# Processing Record 50 of Set 11 | gwadar
# Processing Record 1 of Set 12 | maroantsetra
# Processing Record 2 of Set 12 | bhainsa
# Processing Record 3 of Set 12 | luanda
# Processing Record 4 of Set 12 | kunming
# Processing Record 5 of Set 12 | fairmont
# Processing Record 6 of Set 12 | ranau
# Processing Record 7 of Set 12 | jalu
# Processing Record 8 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 12 | muli
# Processing Record 10 of Set 12 | west fargo
# Processing Record 11 of Set 12 | torbay
# Processing Record 12 of Set 12 | araguatins
# City not found. Skipping...
# Processing Record 13 of Set 12 | yenagoa
# Processing Record 14 of Set 12 | durant
# Processing Record 15 of Set 12 | lipin bor
# Processing Record 16 of Set 12 | kodinar
# Processing Record 17 of Set 12 | inuvik
# Processing Record 18 of Set 12 | necochea
# Processing Record 19 of Set 12 | petatlan
# Processing Record 20 of Set 12 | riviere-au-renard
# Processing Record 21 of Set 12 | hurricane
# Processing Record 22 of Set 12 | chapada dos guimaraes
# Processing Record 23 of Set 12 | ryotsu
# Processing Record 24 of Set 12 | guozhen
# Processing Record 25 of Set 12 | yatou
# Processing Record 26 of Set 12 | maumere
# Processing Record 27 of Set 12 | karabuk
# Processing Record 28 of Set 12 | ardakan
# Processing Record 29 of Set 12 | gombong
# Processing Record 30 of Set 12 | krasnovishersk
# Processing Record 31 of Set 12 | cananea
# Processing Record 32 of Set 12 | tessalit
# Processing Record 33 of Set 12 | ayer itam
# City not found. Skipping...
# Processing Record 34 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 35 of Set 12 | gander
# Processing Record 36 of Set 12 | trelew
# Processing Record 37 of Set 12 | praya
# Processing Record 38 of Set 12 | bhandara
# Processing Record 39 of Set 12 | itaporanga
# Processing Record 40 of Set 12 | lavrentiya
# Processing Record 41 of Set 12 | namatanai
# Processing Record 42 of Set 12 | luangwa
# Processing Record 43 of Set 12 | vila praia de ancora
# Processing Record 44 of Set 12 | fort saint james
# Processing Record 45 of Set 12 | erenhot
# Processing Record 46 of Set 12 | catamarca
# Processing Record 47 of Set 12 | kabompo
# Processing Record 48 of Set 12 | sembakung
# Processing Record 49 of Set 12 | cap-aux-meules
# Processing Record 50 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 1 of Set 13 | stornoway
# Processing Record 2 of Set 13 | oltu
# Processing Record 3 of Set 13 | dunedin
# Processing Record 4 of Set 13 | pedra azul
# Processing Record 5 of Set 13 | san juan
# Processing Record 6 of Set 13 | denpasar
# Processing Record 7 of Set 13 | steyregg
# Processing Record 8 of Set 13 | kula
# Processing Record 9 of Set 13 | zalesovo
# Processing Record 10 of Set 13 | pavullo nel frignano
# Processing Record 11 of Set 13 | wah
# Processing Record 12 of Set 13 | perth
# Processing Record 13 of Set 13 | mazsalaca
# Processing Record 14 of Set 13 | los llanos de aridane
# Processing Record 15 of Set 13 | pout
# Processing Record 16 of Set 13 | khorol
# Processing Record 17 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 19 of Set 13 | ferrol
# Processing Record 20 of Set 13 | gryazovets
# Processing Record 21 of Set 13 | anshun
# Processing Record 22 of Set 13 | husavik
# Processing Record 23 of Set 13 | thinadhoo
# Processing Record 24 of Set 13 | karratha
# Processing Record 25 of Set 13 | raudeberg
# Processing Record 26 of Set 13 | edgewater
# Processing Record 27 of Set 13 | saint-denis
# Processing Record 28 of Set 13 | reyes
# Processing Record 29 of Set 13 | garowe
# Processing Record 30 of Set 13 | kuandian
# Processing Record 31 of Set 13 | presidencia roque saenz pena
# Processing Record 32 of Set 13 | termiz
# Processing Record 33 of Set 13 | grand gaube
# Processing Record 34 of Set 13 | zolotkovo
# Processing Record 35 of Set 13 | tottori
# Processing Record 36 of Set 13 | sambava
# Processing Record 37 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 38 of Set 13 | bathsheba
# Processing Record 39 of Set 13 | grand-lahou
# Processing Record 40 of Set 13 | asilah
# Processing Record 41 of Set 13 | zolotyy potik
# Processing Record 42 of Set 13 | iquitos
# Processing Record 43 of Set 13 | rio muerto
# Processing Record 44 of Set 13 | sao geraldo do araguaia
# Processing Record 45 of Set 13 | coihaique
# Processing Record 46 of Set 13 | fukuma
# Processing Record 47 of Set 13 | tilichiki
# Processing Record 48 of Set 13 | dmitriyevskoye
# Processing Record 49 of Set 13 | paramonga
# Processing Record 50 of Set 13 | anantapur
# Processing Record 1 of Set 14 | champerico
# Processing Record 2 of Set 14 | taltal
# Processing Record 3 of Set 14 | malatya
# Processing Record 4 of Set 14 | batagay-alyta
# Processing Record 5 of Set 14 | salihorsk
# Processing Record 6 of Set 14 | guerrero negro
# Processing Record 7 of Set 14 | conceicao do araguaia
# Processing Record 8 of Set 14 | melilla
# Processing Record 9 of Set 14 | baykit
# Processing Record 10 of Set 14 | coolum beach
# Processing Record 11 of Set 14 | mwinilunga
# Processing Record 12 of Set 14 | ciuruleasa
# Processing Record 13 of Set 14 | lososina
# Processing Record 14 of Set 14 | tianpeng
# Processing Record 15 of Set 14 | tual
# Processing Record 16 of Set 14 | katsuura
# Processing Record 17 of Set 14 | muriti
# Processing Record 18 of Set 14 | sahuaripa
# Processing Record 19 of Set 14 | tegh
# Processing Record 20 of Set 14 | asfi
# Processing Record 21 of Set 14 | treinta y tres
# Processing Record 22 of Set 14 | ucluelet
# Processing Record 23 of Set 14 | bardiyah
# Processing Record 24 of Set 14 | badarganj
# Processing Record 25 of Set 14 | tempoal
# City not found. Skipping...
# Processing Record 26 of Set 14 | ormoz
# Processing Record 27 of Set 14 | ishinomaki
# Processing Record 28 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 14 | ust-kut
# Processing Record 30 of Set 14 | brnakot
# Processing Record 31 of Set 14 | umm kaddadah
# Processing Record 32 of Set 14 | male
# Processing Record 33 of Set 14 | davidson
# Processing Record 34 of Set 14 | roebourne
# Processing Record 35 of Set 14 | kapit
# Processing Record 36 of Set 14 | marapanim
# Processing Record 37 of Set 14 | pascagoula
# Processing Record 38 of Set 14 | seoul
# Processing Record 39 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 14 | baft
# Processing Record 41 of Set 14 | stara vyzhivka
# Processing Record 42 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 43 of Set 14 | bethal
# Processing Record 44 of Set 14 | caohai
# Processing Record 45 of Set 14 | kerewan
# Processing Record 46 of Set 14 | vostok
# Processing Record 47 of Set 14 | weihai
# Processing Record 48 of Set 14 | merauke
# Processing Record 49 of Set 14 | muyezerskiy
# Processing Record 50 of Set 14 | ikot ekpene
# Processing Record 1 of Set 15 | nantucket
# Processing Record 2 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 15 | zhoucheng
# Processing Record 4 of Set 15 | santa rosa
# Processing Record 5 of Set 15 | rio gallegos
# Processing Record 6 of Set 15 | villa constitucion
# Processing Record 7 of Set 15 | partur
# Processing Record 8 of Set 15 | uray
# Processing Record 9 of Set 15 | paamiut
# Processing Record 10 of Set 15 | ushtobe
# Processing Record 11 of Set 15 | mata
# Processing Record 12 of Set 15 | ornskoldsvik
# Processing Record 13 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 14 of Set 15 | greenwood
# Processing Record 15 of Set 15 | la asuncion
# Processing Record 16 of Set 15 | ambunti
# Processing Record 17 of Set 15 | mujiayingzi
# Processing Record 18 of Set 15 | abu dhabi
# Processing Record 19 of Set 15 | el alto
# Processing Record 20 of Set 15 | coos bay
# Processing Record 21 of Set 15 | west bay
# Processing Record 22 of Set 15 | vestbygda
# City not found. Skipping...
# Processing Record 23 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 15 | bulusan
# Processing Record 25 of Set 15 | huaicheng
# Processing Record 26 of Set 15 | altamira
# Processing Record 27 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 28 of Set 15 | port hueneme
# Processing Record 29 of Set 15 | halifax
# Processing Record 30 of Set 15 | berberati
# Processing Record 31 of Set 15 | royan
# Processing Record 32 of Set 15 | srednekolymsk
# Processing Record 33 of Set 15 | trinidad
# Processing Record 34 of Set 15 | terney
# Processing Record 35 of Set 15 | maningrida
# Processing Record 36 of Set 15 | buckeye
# Processing Record 37 of Set 15 | huescar
# Processing Record 38 of Set 15 | baghdad
# Processing Record 39 of Set 15 | unnao
# Processing Record 40 of Set 15 | jieshi
# Processing Record 41 of Set 15 | sioux lookout
# Processing Record 42 of Set 15 | christchurch
# Processing Record 43 of Set 15 | sangar
# Processing Record 44 of Set 15 | acarau
# Processing Record 45 of Set 15 | aldan
# Processing Record 46 of Set 15 | pinyug
# Processing Record 47 of Set 15 | nabire
# Processing Record 48 of Set 15 | jackson
# Processing Record 49 of Set 15 | la ronge
# Processing Record 50 of Set 15 | honiara
# Processing Record 1 of Set 16 | pombas
# Processing Record 2 of Set 16 | sobolevo
# Processing Record 3 of Set 16 | novovarshavka
# Processing Record 4 of Set 16 | vitimskiy
# City not found. Skipping...
# Processing Record 5 of Set 16 | arnoldstein
# Processing Record 6 of Set 16 | naze
# Processing Record 7 of Set 16 | fort-shevchenko
# Processing Record 8 of Set 16 | kawana waters
# City not found. Skipping...
# Processing Record 9 of Set 16 | kangavar
# Processing Record 10 of Set 16 | palmas bellas
# Processing Record 11 of Set 16 | severodvinsk
# Processing Record 12 of Set 16 | mackenzie
# Processing Record 13 of Set 16 | itarema
# Processing Record 14 of Set 16 | puerto del rosario
# Processing Record 15 of Set 16 | tynda
# Processing Record 16 of Set 16 | vanimo
# Processing Record 17 of Set 16 | alto araguaia
# Processing Record 18 of Set 16 | awbari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Voyvozh  62.8920   54.9635    271.93        91         100        3.89
# 1     Rikitea -23.1203 -134.9692    297.30        63          60        2.44
# 2      Manado   1.4870  124.8455    305.58        62          40        4.12
# 3       Goure  13.9835   10.2704    302.39        25          97        3.28
# 4     Ushuaia -54.8000  -68.3000    278.96        75          20        2.57
# 5    Carbonia  39.1672    8.5222    285.93        52          88        1.50
# 6    Karasjok  69.4719   25.5112    273.23        96          98        3.10
# 7  Chokurdakh  70.6333  147.9167    272.00        86          98        1.80
# 8  Ust-Tsilma  65.4410   52.1498    272.33        83          99        4.28
# 9       Pevek  69.7008  170.3133    264.05        90          85        2.96
#
#   Country Current Description                 Date
# 0      RU     overcast clouds  2023-04-27 05:41:27
# 1      PF       broken clouds  2023-04-27 05:41:28
# 2      ID    scattered clouds  2023-04-27 05:41:28
# 3      NE     overcast clouds  2023-04-27 05:41:29
# 4      AR          few clouds  2023-04-27 05:39:08
# 5      IT     overcast clouds  2023-04-27 05:41:30
# 6      NO     overcast clouds  2023-04-27 05:41:31
# 7      RU     overcast clouds  2023-04-27 05:41:32
# 8      RU     overcast clouds  2023-04-27 05:41:33
# 9      RU     overcast clouds  2023-04-27 05:41:33

# %%
city_data_df = city_data_df.drop(columns=['Date'])

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(5)
# Out:
#       City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Voyvozh      RU  62.8920   54.9635    271.93        91         100
# 1  Rikitea      PF -23.1203 -134.9692    297.30        63          60
# 2   Manado      ID   1.4870  124.8455    305.58        62          40
# 3    Goure      NE  13.9835   10.2704    302.39        25          97
# 4  Ushuaia      AR -54.8000  -68.3000    278.96        75          20
#
#    Wind Speed Current Description
# 0        3.89     overcast clouds
# 1        2.44       broken clouds
# 2        4.12    scattered clouds
# 3        3.28     overcast clouds
# 4        2.57          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
